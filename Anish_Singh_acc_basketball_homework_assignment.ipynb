# %%
import pandas as pd

acc_df = pd.read_csv('acc_players-2324F.csv', skiprows = 1)
acc_df.head(5)
# Out:
#    Rk         Player Class Pos          School   G   MP  TRB  AST  STL  ...  \
# 0   1   Amaree Abram    SO   G    Georgia Tech  10  108   17   11    1  ...
# 1   2   Sola Adebisi    FR   F   Florida State   7    9    1    1    0  ...
# 2   3  Prince Aligbe    SO   F  Boston College  35  651  119   21   15  ...
# 3   4     Abe Atiyeh    SR   G  Boston College   4    6    0    0    0  ...
# 4   5    Zack Austin    JR   F      Pittsburgh  33  746  137   29   32  ...
#
#    TOV  PF  PTS    FG%    2P%    3P%    FT%   PER   WS  BPM
# 0    9  10   34  0.262  0.318  0.200  0.615   4.1 -0.1 -6.4
# 1    1   1    2  0.500  0.500    NaN    NaN   3.5  0.0 -6.7
# 2   30  51  164  0.435  0.522  0.147  0.620   9.4  0.9 -1.3
# 3    1   0    3  0.333  0.000  1.000    NaN   1.1  0.0 -8.2
# 4   13  35  216  0.417  0.563  0.295  0.737  18.0  2.9  7.9
#
# [5 rows x 21 columns]

# %%
total_points = acc_df['PTS'].sum()
print("The total points scored by all the players in the acc was", total_points, "points.")
# Out:
# The total points scored by all the players in the acc was 38411 points.

# %%
most_min_df = acc_df[['Player', 'MP']].sort_values(by = "MP", ascending = False).head(1)
print(most_min_df.iloc[0]['Player'], "achieved the most minutes played by player in the acc, with a total of", most_min_df.iloc[0]['MP'], "minutes.")
# Out:
# Casey Morsell achieved the most minutes played by player in the acc, with a total of 1333 minutes.

# %%
top_rebounders_df = acc_df[['Player', 'TRB']].sort_values(by = "TRB", ascending = False).head(5)
print("The top five rebounders in the acc are:", top_rebounders)
# Out:
# The top five rebounders in the acc are:               Player  TRB
# 5      Armando Bacot  380
# 178  Ian Schieffelin  340
# 90   Harrison Ingram  327
# 44    Mohamed Diarra  311
# 149    Norchad Omier  309

# %%
filter_mins_df = acc_df[acc_df['MP'] > 500]
filter_mins_df
# Out:
#       Rk            Player Class Pos          School   G    MP  TRB  AST  STL  \
# 2      3     Prince Aligbe    SO   F  Boston College  35   651  119   21   15
# 4      5       Zack Austin    JR   F      Pittsburgh  33   746  137   29   32
# 5      6     Armando Bacot    SR   F  North Carolina  37  1123  380   56   22
# 7      8     Reece Beekman    SR   G        Virginia  34  1114  124  212   68
# 9     10        Chris Bell    SO   F        Syracuse  32   865   75   21   18
# ..   ...               ...   ...  ..             ...  ..   ...  ...  ...  ...
# 203  204     Jamir Watkins    JR   F   Florida State  33   928  199   91   64
# 206  207         Tre White    SO   G      Louisville  29   907  170   39   24
# 207  208  Chauncey Wiggins    SO   F         Clemson  36   639   76   33    6
# 209  210   Curtis Williams    FR   G      Louisville  32   564   42   20   12
# 215  216    Jaeden Zackery    JR   G  Boston College  36  1216  119  152   63
#
# ...

# %%
highest_ast_over_500_df = filter_mins_df[['Player', 'AST']].sort_values(by = "AST", ascending = False).head(1)
print(highest_ast_over_500_df.iloc[0]['Player'], "achieved the most rebounds out of all players over 500 minutes, with a total of", highest_ast_over_500_df.iloc[0]['AST'], "rebounds.")
# Out:
# Reece Beekman achieved the most rebounds out of all players over 500 minutes, with a total of 212 rebounds.

# %%
top_three_ast_df = acc_df[['Player', 'AST']].sort_values(by = "AST", ascending = False).head(3)
print("The top three assist leaders in the acc are:", top_three_ast_df)
# Out:
# The top three assist leaders in the acc are:              Player  AST
# 7     Reece Beekman  212
# 215  Jaeden Zackery  152
# 21    Elliot Cadeau  150

# %%
top_three_blk_df = acc_df[['Player', 'BLK']].sort_values(by = "BLK", ascending = False).head(3)
print("The top three assist leaders in the acc are:", top_three_blk_df)
# Out:
# The top three assist leaders in the acc are:             Player  BLK
# 51       Ryan Dunn   77
# 157   Quinten Post   61
# 5    Armando Bacot   56

# %%
points_by_school = acc_df.groupby('School')['PTS'].sum()
print("The total points scored by each school in the acc are:")
points_by_school.head(100)
# Out:
# The total points scored by each school in the acc are:
# School
# Boston College    2667
# Clemson           2785
# Duke              2830
# Florida State     2526
# Georgia Tech      2272
# Louisville        2304
# Miami (FL)        2424
# NC State          3101
# North Carolina    3032
# Notre Dame        2113
# Pittsburgh        2495
# Syracuse          2442
# Virginia          2140
# Virginia Tech     2547
# Wake Forest       2733
# Name: PTS, dtype: int64

# %%
assists_by_school = acc_df.groupby('School')['AST'].sum()
print("The total assists achieved by each school in the acc are:")
assists_by_school.head(100)
# Out:
# The total assists achieved by each school in the acc are:
# School
# Boston College    509
# Clemson           533
# Duke              551
# Florida State     406
# Georgia Tech      425
# Louisville        356
# Miami (FL)        454
# NC State          536
# North Carolina    536
# Notre Dame        335
# Pittsburgh        452
# Syracuse          442
# Virginia          509
# Virginia Tech     514
# Wake Forest       429
# Name: AST, dtype: int64

# %%
top_three_schools_by_points_scored = acc_df.groupby('School')['PTS'].sum().sort_values(ascending = False).head(3)
print("The top three schools by points scored are:")
top_three_schools_by_points_scored
# Out:
# The top three schools by points scored are:
# School
# NC State          3101
# North Carolina    3032
# Duke              2830
# Name: PTS, dtype: int64

# %%
top_scorers_df = acc_df[['Player', 'PTS']].sort_values(by = "PTS", ascending = False).head(5)
import matplotlib.pyplot as plt
import seaborn as sns

sns.barplot(x = 'Player', y = 'PTS', data = top_scorers_df)
plt.title('Top Scorers in the ACC')
plt.xlabel('Player')
plt.ylabel('Points Scored')
plt.show()

# %%
import numpy as np
sns.scatterplot(x = 'FG%', y = 'WS', data = acc_df)
plt.title('Field Goal Percentage vs Win Shares')
plt.xlabel('Field Goal Percentage')
plt.ylabel('Win Shares')
plt.show()

# %%
correlation_coefficient = np.corrcoef(acc_df['WS'], acc_df['PTS'])[0, 1]
print("The correlation coefficient is", correlation_coefficient, "which indicates there is a strong positive correlation between win shares and field goal percentage.")
# Out:
# The correlation coefficient is 0.9222241059929768 which indicates there is a strong positive correlation between win shares and field goal percentage.

# %% [markdown]
# #Reflection
#
# The first and most insightful skill I learned was the ability to use and manipulate data to provide me with tangible insights. I started with data points and learned how to sort them by different metrics, such as the maximum, team grouping, and more. I also went from a simple spreadsheet with thousands of data points to finding connections between two completely different metrics, win shares, and field goal percentages. I also learned how to visualize my data in a way that would be consumable for non-technical end users. While telling people that a dataset has a correlation of over 0.9 would be enough for some people, visualizing the data points in a neat scatterplot is much more approachable for a wider audience.
#
# The two most challenging aspects of this project were the syntax and working with some of the quirks of the original dataset. While I often generally knew what I was meant to type into Python to make the code run, sometimes a simple misordering of commands or misnaming of functions would leave me stuck on a particular question for many minutes. Once I figured it out for a few of the problems, however, these slowdowns occurred much less frequently. Also, the original dataset had a few non-normalized features that made it a slight headache to work with initially. For example, it seems that it had an empty row at the very top, which I had to get rid of before I converted it into a Panda data frame. Secondly, the axes of many of the metrics were abbreviated, which was a bit of a hassle sometimes when I had to type them out for my code. To circumnavigate this issue, I looked at a fullscreen version of the original dataset and put it on another monitor so I could look at the names of the columns while I was typing my code.
#
# Data analysis will drastically change almost any field with any data at all in the upcoming years. Just a few decades ago, basketball scouting was led by coaches with no data whatsoever, recruiting players based on experience and "feel". Now, every recruiting decision is data-driven, and this change will also be adopted by other industries with time. Hospitals may alter the priority they give certain patients based on data on which illnesses tend to be the most fatal. The possibilities are endless in every single field of study. This experience helped me with many of the technical aspects of data science and allowed me to gain an appreciation for taking my time before I attempt to tackle a task. Instead of rushing and trying to figure out the code with my current limited knowledge, I should search the documentation on the code in question and understand exactly what it is I am trying to do with my data. By doing this, I increase my knowledge bank and will be better prepared for future situations, even if I do not have time to search for documentation then.
